# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Project-goal" data-toc-modified-id="Project-goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Project goal</a></span></li><li><span><a href="#Project-Datasets" data-toc-modified-id="Project-Datasets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project Datasets</a></span></li><li><span><a href="#Data-Gathering" data-toc-modified-id="Data-Gathering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Gathering</a></span><ul class="toc-item"><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Importing Libraries</a></span></li><li><span><a href="#Gathering-Data" data-toc-modified-id="Gathering-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Gathering Data</a></span><ul class="toc-item"><li><span><a href="#Gathering-Data-Programmatically" data-toc-modified-id="Gathering-Data-Programmatically-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Gathering Data Programmatically</a></span></li><li><span><a href="#Gathering-Data-Manually" data-toc-modified-id="Gathering-Data-Manually-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Gathering Data Manually</a></span></li><li><span><a href="#Gathering-Data-by-API" data-toc-modified-id="Gathering-Data-by-API-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Gathering Data by API</a></span></li></ul></li></ul></li><li><span><a href="#Data-Assessing" data-toc-modified-id="Data-Assessing-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Assessing</a></span><ul class="toc-item"><li><span><a href="#image_data:-This-is-mainly-image-prediction-data" data-toc-modified-id="image_data:-This-is-mainly-image-prediction-data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>image_data: This is mainly image prediction data</a></span></li><li><span><a href="#df_archive-data" data-toc-modified-id="df_archive-data-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>df_archive data</a></span></li><li><span><a href="#df_json-data" data-toc-modified-id="df_json-data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>df_json data</a></span></li><li><span><a href="#Quality-issues" data-toc-modified-id="Quality-issues-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Quality issues</a></span></li><li><span><a href="#Tidiness-issues" data-toc-modified-id="Tidiness-issues-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Tidiness issues</a></span></li></ul></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Tidiness-Issues" data-toc-modified-id="Tidiness-Issues-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Tidiness Issues</a></span><ul class="toc-item"><li><span><a href="#Issue-1" data-toc-modified-id="Issue-1-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Issue 1</a></span></li><li><span><a href="#Issue-2" data-toc-modified-id="Issue-2-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Issue 2</a></span></li></ul></li><li><span><a href="#Quality-Issues" data-toc-modified-id="Quality-Issues-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Quality Issues</a></span><ul class="toc-item"><li><span><a href="#Issue-1" data-toc-modified-id="Issue-1-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Issue 1</a></span></li><li><span><a href="#Issue-2" data-toc-modified-id="Issue-2-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Issue 2</a></span></li><li><span><a href="#Issue-3" data-toc-modified-id="Issue-3-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Issue 3</a></span></li><li><span><a href="#Issue-4" data-toc-modified-id="Issue-4-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Issue 4</a></span></li><li><span><a href="#Issue-5" data-toc-modified-id="Issue-5-5.2.5"><span class="toc-item-num">5.2.5&nbsp;&nbsp;</span>Issue 5</a></span></li><li><span><a href="#Issue-6" data-toc-modified-id="Issue-6-5.2.6"><span class="toc-item-num">5.2.6&nbsp;&nbsp;</span>Issue 6</a></span></li><li><span><a href="#Issue-7" data-toc-modified-id="Issue-7-5.2.7"><span class="toc-item-num">5.2.7&nbsp;&nbsp;</span>Issue 7</a></span></li><li><span><a href="#Issue-8" data-toc-modified-id="Issue-8-5.2.8"><span class="toc-item-num">5.2.8&nbsp;&nbsp;</span>Issue 8</a></span></li><li><span><a href="#Issue-9" data-toc-modified-id="Issue-9-5.2.9"><span class="toc-item-num">5.2.9&nbsp;&nbsp;</span>Issue 9</a></span></li></ul></li></ul></li><li><span><a href="#Storing-Data" data-toc-modified-id="Storing-Data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Storing Data</a></span></li><li><span><a href="#Analyzing-and-Visualizing-Data" data-toc-modified-id="Analyzing-and-Visualizing-Data-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Analyzing and Visualizing Data</a></span><ul class="toc-item"><li><span><a href="#Insight-1:" data-toc-modified-id="Insight-1:-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Insight 1:</a></span><ul class="toc-item"><li><span><a href="#Interpretation:" data-toc-modified-id="Interpretation:-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Interpretation:</a></span></li></ul></li><li><span><a href="#Insight-2:" data-toc-modified-id="Insight-2:-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Insight 2:</a></span><ul class="toc-item"><li><span><a href="#Interpretation:" data-toc-modified-id="Interpretation:-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Interpretation:</a></span></li></ul></li><li><span><a href="#Insight-3:" data-toc-modified-id="Insight-3:-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Insight 3:</a></span><ul class="toc-item"><li><span><a href="#Interpretation:" data-toc-modified-id="Interpretation:-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Interpretation:</a></span></li></ul></li><li><span><a href="#Insight-4:" data-toc-modified-id="Insight-4:-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Insight 4:</a></span><ul class="toc-item"><li><span><a href="#Interpretation:" data-toc-modified-id="Interpretation:-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Interpretation:</a></span></li></ul></li><li><span><a href="#Insight-5:" data-toc-modified-id="Insight-5:-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Insight 5:</a></span><ul class="toc-item"><li><span><a href="#Interpretation:" data-toc-modified-id="Interpretation:-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Interpretation:</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Project goal
#
# > Wrangle WeRateDogs Twitter data to create interesting and trustworthy analyses and visualizations.

# %% [markdown]
# ## Project Datasets
#
# **i. Enhanced Twitter Archive**
#
# > The WeRateDogs Twitter archive contains basic tweet data for all 5000+ of their tweets, but not everything. One column the archive does contain though: each tweet's text, which was used to extract rating, dog name, and dog "stage" (i.e. doggo, floofer, pupper, and puppo) to make this Twitter archive "enhanced." Of the 5000+ tweets,  they have filtered for tweets with ratings only (there are 2356). They extracted this data programmatically, but they didn't do a very good job.
#
# **ii. Additional Data via the Twitter API**
#
# > Back to the basic of Twitter archives: retweet count and favorite count are two of the notable column omissions. Fortunately, this additional data can be gathered by anyone from Twitter's API. Well, "anyone" who has access to data for the 3000 most recent tweets, at least. However, we have the WeRateDogs Twitter archive and specifically the tweet IDs within it, can gather this data for all 5000+. I queried **Twitter's API** to gather this valuable data.
#
# > Gathering each tweet's retweet count and favorite ("like") count at the minimum and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file.
#
# > Each tweet's JSON data was written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count.
#
# **iii. Image Predictions File**
#
# > They ran every image in the WeRateDogs Twitter archive through a neural network that can classify breeds of dogs*. The results: a table full of image predictions (the top three only) alongside each tweet ID, image URL, and the image number that corresponded to the most confident prediction (numbered 1 to 4 since tweets can have up to four images). This also will be assessed and cleaned

# %% [markdown]
# ## Data Gathering
#
# This will follow through from three sources:
# - Load and import file programmatically (the url to the source file is provided by Udacity)
# - Import file manually (this file is provided directly by Udacity)
# - Extract and import data via API (the focus will be Twitter API where tweet ids will be used to extract tweet data as a JSON file)

# %% [markdown]
# ### Importing Libraries

# %%
# importing libraries 

import pandas as pd
import numpy as np
import requests
import os
import seaborn as sns
import matplotlib.pyplot as plt 
import time
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
# %matplotlib inline

# %% [markdown]
# ### Gathering Data
# #### Gathering Data Programmatically

# %% [markdown]
# `1. Load and import file programmatically (the url to the source file is provided by Udacity)`

# %%
# Make directory if it doesn't already exist
# this will save source file image_predictions.tsv
# which is stored in udacity server

folder_name = 'tweet_image'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
## the url of the data source image_predictions.tsv
## stored in udacity server

url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'

## then request to get the file (image_predictions.tsv) from the server 

response = requests.get(url)

## opening the file image_predictions.tsv

with open(os.path.join(folder_name, url.split('/')[-1]), mode = 'wb') as file:
    file.write(response.content)

# %% [markdown]
# #### Gathering Data Manually

# %%
# Importing the image prediction file
# And storing the file as image_data

image_data = pd.read_csv('image-predictions.tsv', sep="\t")
image_data.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# `2. Import file manually (this file is provided directly by Udacity)`

# %%
# Importing the twitter archive data file
# storing the file as df_archive

df_archive = pd.read_csv('twitter-archive-enhanced.csv')
df_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# #### Gathering Data by API

# %% [markdown]
# `3. Extract and import data via API (the focus will be Twitter API where tweet ids will be used to extract tweet data as a JSON file)`

# %%
## Twitter credentials for authorization
## After running this cell with the credentials, they will be hidden
## Because of Twitter key and secret confidentialities

consumer_key = " "
consumer_secret = " "
access_token = " "
access_secret = " "

## Initializing OAuthHandler with all four credentials 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# Initializing API with the auth instance
api = tweepy.API(auth, wait_on_rate_limit=True)

## Getting the tweet ids for which data will be gathered
tweet_ids = df_archive.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in
# the Twitter archive
count = 0
fails_dict = {} # Gathered each tweet ids we assummed perhaps they were deleted 
start = timer() # Starting time


# Saving each JSON tweet in a text file as a line in the file
with open('tweet_json.txt', 'w') as outfile:
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.errors.TweepyException as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer() # Ending time
print(end - start)
# Printing the status of the ran tweet ids that fail
# Assummed deleted tweets 
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %% [markdown]
# Getting the above result into csv as the third file for the project

# %%
# Extract the needed data from json and 
# make them as DataFrame 

temp = []

# Open the text_json.txt file 
with open('tweet_json.txt', encoding='utf-8') as json_file:
    for i in json_file:
        data = json.loads(i) 
        tweet_id = data['id'] # Extract the id data from the json file 
        tweet = data['full_text'] # Extract the text data (tweet) from the json file 
        tweet_url = tweet[tweet.find('https'):] # Extract the tweet url for the text data (tweet)
        favorite_count = data['favorite_count'] # Extract the like count of the tweet 
        retweet_count = data['retweet_count'] # Extract the retweet count of the tweet 
        retweet_status = data['retweet_status'] = data.get('retweet_status', 'Original tweet') # Where only the original tweet is retweeted 
        if retweet_status == 'Original tweet':
            url = tweet_url
        else:
            retweeted_status = 'A retweet'
            url = 'A retweet'
        
    
        temp.append({'tweet_id': tweet_id,'favorite_count': favorite_count,'retweet_status': retweet_status,
                     'url': url,'retweet_count': retweet_count}) # Appending temp with the extracted data

# create a new DataFrame 
df_new = pd.DataFrame(temp, columns = ['tweet_id', 'favorite_count','retweet_count', 'retweet_status', 'url'])
                                          
                                                           
df_new.head()

# Saving the file to csv 
df_new.to_csv('tweet_json.txt', index=False)

# %%
# Importing the saved csv 

df_json = pd.read_csv('tweet_json.txt')
df_json.head()
# Out:
#              tweet_id  favorite_count  retweet_count  retweet_status  \
# 0  892420643555336193           33810           7010  Original tweet
# 1  892177421306343426           29323           5302  Original tweet
# 2  891815181378084864           22062           3482  Original tweet
# 3  891689557279858688           36913           7220  Original tweet
# 4  891327558926688256           35285           7764  Original tweet
#
#                        url
# 0  https://t.co/MgUWQ76dJU
# 1  https://t.co/0Xxu71qeIV
# 2  https://t.co/wUnZnhtVJB
# 3  https://t.co/tD36da7qLQ
# 4  https://t.co/AtUZn91f7f

# %% [markdown]
# After the gathering processes, we are left with three datasets:
# 1. image_data
# 2. df_archive
# 3. df_json
#
# The three datasets will be further processed and cleaned

# %% [markdown]
# ##  Data Assessing
#
# To-do, quality and tidiness issues:
# - Check and note missing data
# - Check and note down duplicated data
# - Check some other issues
#
# **Note: For this project, only 8 quality and 2 tidiness issues will be our focus**
#
# Data Visuals for all the datasets for assessing
#
# ### image_data: This is mainly image prediction data

# %%
image_data.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
image_data.shape
# Out:
# (2075, 12)

# %%
image_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_data.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# ...

# %% [markdown]
# Let's check the number of unique dog breed predicted by the different algorithms **(p1, p2, and p3)**

# %%
image_data.p1.nunique(), image_data.p2.nunique(), image_data.p3.nunique()
# Out:
# (378, 405, 408)

# %%
print(image_data.p1.value_counts())
print(image_data.p2.value_counts())
print(image_data.p3.value_counts())
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# coil                    1
# timber_wolf             1
# water_buffalo           1
# damselfly               1
# tricycle                1
# Name: p1, Length: 378, dtype: int64
# Labrador_retriever    104
# golden_retriever       92
# Cardigan               73
# Chihuahua              44
# Pomeranian             42
#                      ...
# pickup                  1
# folding_chair           1
# bow                     1
# bagel                   1
# accordion               1
# Name: p2, Length: 405, dtype: int64
# Labrador_retriever    79
# Chihuahua             58
# golden_retriever      48
# Eskimo_dog            38
# kelpie                35
#                       ..
# barber_chair           1
# goldfish               1
# chest                  1
# neck_brace             1
# wok                    1
# ...

# %%
# Checking if the images supplied to the algorithms are unique all through 
# This will be done through jpg_url

image_data.jpg_url.nunique()
# Out:
# 2009

# %% [markdown]
# `With the above result, there must be some repeated images through the jpg_url. Let's confirm this by value counts`

# %%
image_data.jpg_url.value_counts()[:40]
# Out:
# https://pbs.twimg.com/media/C2kzTGxWEAEOpPL.jpg                                            2
# https://pbs.twimg.com/media/CiyHLocU4AI2pJu.jpg                                            2
# https://pbs.twimg.com/media/C3nygbBWQAAjwcW.jpg                                            2
# https://pbs.twimg.com/media/CWza7kpWcAAdYLc.jpg                                            2
# https://pbs.twimg.com/media/CrXhIqBW8AA6Bse.jpg                                            2
# https://pbs.twimg.com/media/Cq9guJ5WgAADfpF.jpg                                            2
# https://pbs.twimg.com/media/CzG425nWgAAnP7P.jpg                                            2
# https://pbs.twimg.com/media/CsVO7ljW8AAckRD.jpg                                            2
# https://pbs.twimg.com/media/CsGnz64WYAEIDHJ.jpg                                            2
# https://pbs.twimg.com/media/CwJR1okWIAA6XMp.jpg                                            2
# ...

# %%
image_data.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
from IPython.display import Image 

im_1 = Image(url = ' https://pbs.twimg.com/media/CkjMx99UoAM2B1a.jpg')
display(im_1)
# Out:
# <img src=" https://pbs.twimg.com/media/CkjMx99UoAM2B1a.jpg"/>

# %% [markdown]
# Check the value count for each algorithm for the predicted breed

# %%
# Checking duplicates

image_data.duplicated().sum()
# Out:
# 0

# %%
# Checking missing data

image_data.isna().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
image_data.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
image_data.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 1754  824775126675836928  https://pbs.twimg.com/media/C3Iwlr0WYAARVh4.jpg
# 883   698907974262222848  https://pbs.twimg.com/media/CbMFFssWIAAyuOd.jpg
# 979   707297311098011648  https://pbs.twimg.com/media/CdDTJLMW4AEST--.jpg
# 963   705975130514706432  https://pbs.twimg.com/media/CcwgjmuXIAEQoSd.jpg
# 1601  799774291445383169  https://pbs.twimg.com/media/CsGnz64WYAEIDHJ.jpg
#
#       img_num                           p1   p1_conf  p1_dog  \
# 1754        1               Border_terrier  0.610499    True
# 883         3  German_short-haired_pointer  0.983131    True
# 979         1             Blenheim_spaniel  0.370717    True
# 963         1    Staffordshire_bullterrier  0.587764    True
# 1601        1                         chow  0.316565    True
#
#                                   p2   p2_conf  p2_dog  \
# 1754                        malinois  0.090291    True
# ...

# %% [markdown]
# ### df_archive data

# %%
df_archive.head(10)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
# 5  891087950875897856                    NaN                  NaN
# 6  890971913173991426                    NaN                  NaN
# 7  890729181411237888                    NaN                  NaN
# 8  890609185150312448                    NaN                  NaN
# 9  890240255349198849                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
# 5  2017-07-29 00:08:17 +0000
# ...

# %%
df_archive.expanded_urls[:10]
# Out:
# 0    https://twitter.com/dog_rates/status/892420643...
# 1    https://twitter.com/dog_rates/status/892177421...
# 2    https://twitter.com/dog_rates/status/891815181...
# 3    https://twitter.com/dog_rates/status/891689557...
# 4    https://twitter.com/dog_rates/status/891327558...
# 5    https://twitter.com/dog_rates/status/891087950...
# 6    https://gofundme.com/ydvmve-surgery-for-jax,ht...
# 7    https://twitter.com/dog_rates/status/890729181...
# 8    https://twitter.com/dog_rates/status/890609185...
# 9    https://twitter.com/dog_rates/status/890240255...
# Name: expanded_urls, dtype: object

# %%
df_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
# Checking number of duplicates

df_archive.duplicated().sum()
# Out:
# 0

# %%
# Checking missing data

df_archive.isna().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
# value counts for dog names 

df_archive.name.value_counts()[:60]
# Out:
# None        745
# a            55
# Charlie      12
# Oliver       11
# Lucy         11
# Cooper       11
# Penny        10
# Lola         10
# Tucker       10
# Bo            9
# Winston       9
# Sadie         8
# the           8
# Daisy         7
# Toby          7
# Buddy         7
# Bailey        7
# an            7
# Jack          6
# Rusty         6
# Scout         6
# Bella         6
# Jax           6
# Dave          6
# Stanley       6
# Milo          6
# Koda          6
# Oscar         6
# Leo           6
# Gus           5
# very          5
# Oakley        5
# Phil          5
# Chester       5
# Bentley       5
# Alfie         5
# Louis         5
# Sunny         5
# Larry         5
# Sammy         5
# George        5
# Finn          5
# Hank          4
# Cassie        4
# Riley         4
# Maggie        4
# Brody         4
# Reginald      4
# Derek         4
# Scooter       4
# Gerald        4
# one           4
# Reggie        4
# Jerry         4
# Sampson       4
# ...

# %%
df_archive.query('name == "None"')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# ...

# %%
df_archive.query('name == "a"')
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %% [markdown]
# Checking the value count for each dog breed features

# %%
print(df_archive.doggo.value_counts())
print(df_archive.floofer.value_counts())
print(df_archive.pupper.value_counts())
print(df_archive.puppo.value_counts())
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64
# None       2346
# floofer      10
# Name: floofer, dtype: int64
# None      2099
# pupper     257
# Name: pupper, dtype: int64
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
df_archive.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 0         2
# 15        2
# 75        2
# 420       2
# 182       1
# 204       1
# 143       1
# 121       1
# 99        1
# 20        1
# 45        1
# 27        1
# 17        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 80        1
# 84        1
# 88        1
# 1776      1
# 960       1
# 666       1
# 144       1
# 165       1
# Name: rating_numerator, dtype: int64

# %%
df_archive.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 20        2
# 80        2
# 0         1
# 120       1
# 7         1
# 170       1
# 150       1
# 130       1
# 90        1
# 110       1
# 2         1
# 70        1
# 40        1
# 16        1
# 15        1
# Name: rating_denominator, dtype: int64

# %%
df_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
df_archive.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2004  672466075045466113                    NaN                  NaN
# 550   804738756058218496                    NaN                  NaN
# 202   853639147608842240                    NaN                  NaN
# 1847  675820929667219457                    NaN                  NaN
# 1993  672609152938721280                    NaN                  NaN
#
#                       timestamp  \
# 2004  2015-12-03 17:23:00 +0000
# 550   2016-12-02 17:27:25 +0000
# 202   2017-04-16 16:00:07 +0000
# 1847  2015-12-12 23:34:00 +0000
# 1993  2015-12-04 02:51:33 +0000
#
#                                                  source  \
# 2004  <a href="http://twitter.com/download/iphone" r...
# 550   <a href="http://twitter.com/download/iphone" r...
# 202   <a href="http://twitter.com/download/iphone" r...
# 1847  <a href="http://twitter.com/download/iphone" r...
# 1993  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### df_json data

# %%
df_json.head()
# Out:
#              tweet_id  favorite_count  retweet_count  retweet_status  \
# 0  892420643555336193           33810           7010  Original tweet
# 1  892177421306343426           29323           5302  Original tweet
# 2  891815181378084864           22062           3482  Original tweet
# 3  891689557279858688           36913           7220  Original tweet
# 4  891327558926688256           35285           7764  Original tweet
#
#                        url
# 0  https://t.co/MgUWQ76dJU
# 1  https://t.co/0Xxu71qeIV
# 2  https://t.co/wUnZnhtVJB
# 3  https://t.co/tD36da7qLQ
# 4  https://t.co/AtUZn91f7f

# %%
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2326 non-null   int64
#  1   favorite_count  2326 non-null   int64
#  2   retweet_count   2326 non-null   int64
#  3   retweet_status  2326 non-null   object
#  4   url             2326 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.0+ KB

# %%
df_json.sample(50)
# Out:
#                 tweet_id  favorite_count  retweet_count  retweet_status  \
# 69    879008229531029506           16771           2244  Original tweet
# 2303  666337882303524864             168             79  Original tweet
# 1907  673919437611909120            1057            327  Original tweet
# 1719  679047485189439488            2057            587  Original tweet
# 606   795076730285391872           15348           5107  Original tweet
# 1237  709901256215666688             609             92  Original tweet
# 2198  668256321989451776            1154            518  Original tweet
# 1594  684902183876321280            1719            467  Original tweet
# 1362  700151421916807169            2058            611  Original tweet
# 722   780476555013349377               0            103  Original tweet
# 1484  691096613310316544            2769            797  Original tweet
# 524   805958939288408065               0           5020  Original tweet
# ...

# %%
# check for any sample that had a retweet not original tweet 

df_json.retweet_status.value_counts()
# Out:
# Original tweet    2326
# Name: retweet_status, dtype: int64

# %%
df_json.sample(60)
# Out:
#                 tweet_id  favorite_count  retweet_count  retweet_status  \
# 2304  666293911632134144             426            291  Original tweet
# 574   798705661114773508               0           6225  Original tweet
# 2204  668190681446379520             577            171  Original tweet
# 1463  692894228850999298            2091            720  Original tweet
# 1883  674372068062928900             767            280  Original tweet
# 1050  739485634323156992            6615           2645  Original tweet
# 942   750117059602808832            4062           1213  Original tweet
# 982   747461612269887489            3601            950  Original tweet
# 1848  675047298674663426             929            275  Original tweet
# 645   790698755171364864            7812           1809  Original tweet
# 2011  671542985629241344             965            487  Original tweet
# 391   823333489516937216             660             22  Original tweet
# ...

# %%
# Checking duplicates

df_json.duplicated().sum()
# Out:
# 0

# %%
# Checking missing data

df_json.isna().sum()
# Out:
# tweet_id          0
# favorite_count    0
# retweet_count     0
# retweet_status    0
# url               0
# dtype: int64

# %%
df_json.describe()
# Out:
#            tweet_id  favorite_count  retweet_count
# count  2.326000e+03     2326.000000    2326.000000
# mean   7.418142e+17     7056.319433    2473.137575
# std    6.821493e+16    10960.961549    4187.099073
# min    6.660209e+17        0.000000       1.000000
# 25%    6.780814e+17     1224.500000     495.500000
# 50%    7.180382e+17     3052.500000    1150.000000
# 75%    7.986600e+17     8608.750000    2863.750000
# max    8.924206e+17   144850.000000   70778.000000

# %% [markdown]
# Since we'll be joining all the dataframe on tweet_id, let's check if all the tweet_id in all the dataframe are the same and have equal length

# %%
from pandas import testing as tm 

#tm.assert_series_equal(df_archive.tweet_id, df_json.tweet_id)

# %%
#tm.assert_series_equal(df_archive.tweet_id, image_data.tweet_id)

# %%
#tm.assert_series_equal(image_data.tweet_id, df_json.tweet_id)

# %% [markdown]
# All the tweet_id series in all dataframe are not equal in length

# %% [markdown]
# ### Quality issues
# 1. There are retweets in the dataset (df_archive)
#
# 2. More than 60% of data in `in_reply_to_status_id`, `in_reply_to_user_id`, `retweeted_status_id`, `retweeted_status_user_id` and `retweeted_status_timestamp` columns are missing data.
#
# 3. Tweet_id column not in string datatype (for all the datasets)
#
# 4. Img_num feature is not in correct datatype (image_data)
#
# 5. Timestamp feature not in datetime datatype (df_archive)
#
# 6. Incorrect datatype for name column (df_archive)
#
# 7. There is mixture uppercase and lowercase in p1, p2, and p3 columns (image_data)
#
# 8. Names of some dogs are not correct (df_archive)
#
# 9. Expanded_url column has 59 missing expanded_urls

# %% [markdown]
# ### Tidiness issues
# 1. Separate columns for dog breeds
# 2. All the datasets not in a single dataset

# %% [markdown]
# ## Data Cleaning
#
# We would deal with all the fact checked issues

# %%
# Make copies of original pieces of data

tweet_df = df_archive.copy()
json_df = df_json.copy()
image = image_data.copy()

# %% [markdown]
# ### Tidiness Issues
# #### Issue 1
# tweet_df: dog breeds are splitted to different columns as stand alone feature**

# %% [markdown]
# **Define**
#
# doggo, floofer, pupper, and puppo variables will be collapsed to a single categorical variable as dog_breed

# %% [markdown]
# **Code**
#
# Lets check a situation where an observation of a dog would have more than one occurence of dog breed.
#
# We would count each occurence of dog breed and where dog breed is not explicit (represented by **None**)

# %%
#Viewing the data 

tweet_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
tweet_df.groupby(["doggo", "floofer", "pupper", "puppo"]).size().reset_index().rename(columns={0: "occurence_count"})
# Out:
#    doggo  floofer  pupper  puppo  occurence_count
# 0   None     None    None   None             1976
# 1   None     None    None  puppo               29
# 2   None     None  pupper   None              245
# 3   None  floofer    None   None                9
# 4  doggo     None    None   None               83
# 5  doggo     None    None  puppo                1
# 6  doggo     None  pupper   None               12
# 7  doggo  floofer    None   None                1

# %% [markdown]
# We can see that:
# - a sample tweet of a dog have both **doggo** and **puppo** as dog breed
# - 12 sample tweets of dogs have both **doggo** and **pupper** as dog breed
# - a sample tweet of a dog have both **doggo** and **floofer** as dog breed
#
# In a situation like the above, they will be categorized as **multi-type** dog breed

# %%
## Shrinking the dog breeds together to new column dog_breed

tweet_df['dog_breed'] = tweet_df.doggo + tweet_df.floofer + tweet_df.pupper + tweet_df.puppo

# %%
tweet_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
tweet_df.dog_breed.value_counts()
# Out:
# NoneNoneNoneNone        1976
# NoneNonepupperNone       245
# doggoNoneNoneNone         83
# NoneNoneNonepuppo         29
# doggoNonepupperNone       12
# NoneflooferNoneNone        9
# doggoNoneNonepuppo         1
# doggoflooferNoneNone       1
# Name: dog_breed, dtype: int64

# %% [markdown]
# >Make a for loop to represent the value in dog_breed to the original dog breed

# %%
for index, row in tweet_df.iterrows():
    """
    This will loop through the value in each cell of dog_breed,  
    create a new column of the dog breed....
    Also, multi_type will represent dog with more one dog breed.
    """
    if ('NoneNoneNoneNone' in row['dog_breed']):
        tweet_df.loc[index, 'dog_breed_updated'] = None
    elif ('NoneNonepupperNone' in row['dog_breed']):
        tweet_df.loc[index, 'dog_breed_updated'] = 'pupper'
    elif ('doggoNoneNoneNone' in row['dog_breed']):
        tweet_df.loc[index, 'dog_breed_updated'] = 'doggo'
    elif ('NoneNoneNonepuppo' in row['dog_breed']):
        tweet_df.loc[index, 'dog_breed_updated'] = 'puppo'
    elif ('NoneflooferNoneNone' in row['dog_breed']):
        tweet_df.loc[index, 'dog_breed_updated'] = 'floofer'
    else:
        tweet_df.loc[index, 'dog_breed_updated'] = 'multi_type'

# %%
tweet_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# **Test**

# %%
tweet_df.dog_breed_updated.value_counts()
# Out:
# pupper        245
# doggo          83
# puppo          29
# multi_type     14
# floofer         9
# Name: dog_breed_updated, dtype: int64

# %%
# Drop dog_breed and other columns related to dog breed 
# Aside a dog_breed_updated

tweet_df.drop(['dog_breed', 'doggo', 'floofer', 'pupper', 'puppo'], axis=1, inplace=True)

# %%
tweet_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# #### Issue 2
# All the datasets not in a single dataset

# %% [markdown]
# **Define**
# - Merge all the datasets together on tweet id to create a single dataset (image_data, df_archive, and df_json)
# - Using the python function **merge** to combine all the datasets [tweet_df, image, and json_df]

# %% [markdown]
# **Code**

# %%
df_one = pd.merge(tweet_df, right=json_df, how="outer", on="tweet_id")
df_one = pd.merge(df_one, right=image, how="outer", on="tweet_id")
df_one
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# **Test**

# %%
df_one.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_one.dog_breed_updated.value_counts()
# Out:
# pupper        245
# doggo          83
# puppo          29
# multi_type     14
# floofer         9
# Name: dog_breed_updated, dtype: int64

# %%
list(df_one.columns)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'dog_breed_updated',
#  'favorite_count',
#  'retweet_count',
#  'retweet_status',
#  'url',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %% [markdown]
#     All the noted TIDINESS ISSUES have been solved.
#
#     We move to QUALITY ISSUES

# %% [markdown]
# ### Quality Issues
# #### Issue 1
#
# There are retweet samples in the df_one dataset
#
# **Define**
#
# Remove all rows that have values (not blank or non-null) in `retweeted_status_id`, `retweeted_status_user_id`, and `retweeted_status_timestamp` columns.
#
# **Code**

# %%
df_one = df_one[df_one.retweeted_status_id.isnull()]
df_one = df_one[df_one.retweeted_status_user_id.isnull()]
df_one = df_one[df_one.retweeted_status_timestamp.isnull()]

# %% [markdown]
# **Test**

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   object
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        2175 non-null   object
# ...

# %% [markdown]
# #### Issue 2
#
# Missing records of more than 60%;
# - in_reply_to_status_id
# - in_reply_to_user_id
# - retweeted_status_id
# - retweeted_status_user_id
# - retweeted_status_timestamp

# %% [markdown]
# **Define**
#
# Since the above columns have more than 60% missing records and there is no way to recover or update the record, those columns will be dropped

# %% [markdown]
# **Code**

# %%
## Dropping the columns

df_one.drop(['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id','retweeted_status_user_id', 'retweeted_status_timestamp'], axis=1, inplace=True)

# %% [markdown]
# **Test**

# %%
df_one.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# #### Issue 3
# Tweet_id column should be in string datatype not integer

# %% [markdown]
# **Define**
#
# Convert tweet_id datatype to string

# %% [markdown]
# **Code**

# %%
df_one['tweet_id'] = df_one['tweet_id'].astype(str)

# %% [markdown]
# **Test**

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   object
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2117 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   object
#  8   dog_breed_updated   344 non-null    object
#  9   favorite_count      2166 non-null   float64
#  10  retweet_count       2166 non-null   float64
#  11  retweet_status      2166 non-null   object
#  12  url                 2166 non-null   object
#  13  jpg_url             1994 non-null   object
#  14  img_num             1994 non-null   float64
# ...

# %% [markdown]
# #### Issue 4
# Img_num feature is not in correct datatype, it should be in **categorical datatype**
#
#
# **Define**
#
# Convert img_num to categorical datatype using **astype()**
#
# **Code**

# %%
df_one['img_num'] = df_one['img_num'].astype('category')

# %% [markdown]
# **Test**

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   object
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2117 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   object
#  8   dog_breed_updated   344 non-null    object
#  9   favorite_count      2166 non-null   float64
#  10  retweet_count       2166 non-null   float64
#  11  retweet_status      2166 non-null   object
#  12  url                 2166 non-null   object
#  13  jpg_url             1994 non-null   object
#  14  img_num             1994 non-null   category
# ...

# %% [markdown]
# #### Issue 5
# Timestamp column should be in datetime datatype
#
#
# **Define**
# - Remove the timezone from the timestamp column by slicing
# - Convert timestamp column to datetime datatype using **.to_datetime()** function
#
# **Code**

# %%
##Remove the timezone

df_one['timestamp'] = df_one['timestamp'].str.slice(start=0, stop=-6)

## Change timestamp to datetime format

df_one['timestamp'] = pd.to_datetime(df_one['timestamp'], format = "%Y-%m-%d %H:%M:%S")

# %% [markdown]
# **Test**

# %%
df_one.head(3)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
#
# ...

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   datetime64[ns]
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2117 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   object
#  8   dog_breed_updated   344 non-null    object
#  9   favorite_count      2166 non-null   float64
#  10  retweet_count       2166 non-null   float64
#  11  retweet_status      2166 non-null   object
#  12  url                 2166 non-null   object
#  13  jpg_url             1994 non-null   object
#  14  img_num             1994 non-null   category
# ...

# %% [markdown]
# #### Issue 6
# Incorrect datatype for name column, it should be in categorical datatype
#
#
# **Define**
# - Convert name column to categorical datatype
#
# **Code**

# %%
df_one['name'] = df_one['name'].astype('category')

# %% [markdown]
# **Test**

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   datetime64[ns]
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2117 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   category
#  8   dog_breed_updated   344 non-null    object
#  9   favorite_count      2166 non-null   float64
#  10  retweet_count       2166 non-null   float64
#  11  retweet_status      2166 non-null   object
#  12  url                 2166 non-null   object
#  13  jpg_url             1994 non-null   object
#  14  img_num             1994 non-null   category
# ...

# %% [markdown]
# #### Issue 7
# - Uppercase and lowercase mixture in p1, p2, and p3 columns (image_data)
# - The values should either be Uppercase or Lowercase all through
#
#
# **Define**
# - Convert p1, p2, and p3 columns values to lowercase all through
#
# **Code**

# %%
df_one.p1 = df_one.p1.str.lower()
df_one.p2 = df_one.p2.str.lower()
df_one.p3 = df_one.p3.str.lower()

# %% [markdown]
# **Test**

# %%
print(df_one.p1.sample(10))
print(df_one.p2.sample(10))
print(df_one.p3.sample(10))
# Out:
# 1525                       pembroke
# 45                 golden_retriever
# 1254    soft-coated_wheaten_terrier
# 1798                  common_iguana
# 454                           swing
# 214                        web_site
# 1334                      chihuahua
# 1892                       seashore
# 1923                     pomeranian
# 715                           quilt
# Name: p1, dtype: object
# 2000                     rottweiler
# 2171                     eskimo_dog
# 513                             NaN
# 269                             NaN
# 1677                    siamese_cat
# 988                        bluetick
# 1485                          lhasa
# 734               italian_greyhound
# 338     german_short-haired_pointer
# 136                      pomeranian
# Name: p2, dtype: object
# 1168                       tub
# 732         labrador_retriever
# 1551    welsh_springer_spaniel
# 444                        NaN
# 1498                   polecat
# ...

# %% [markdown]
# #### Issue 8
# - Expanded_url column has 59 missing expanded_urls
# - The missing data in expanded_urls is correlated to the other columns with missing data
#
#
# **Define**
# - Drop the rows with missing data of expanded_urls
#
# **Code**

# %%
## View all the columns of the dataframe 

pd.set_option('display.max_columns', None)
df_one.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %%
## Set the dataframe result
## to see the full cell values

pd.set_option('display.max_colwidth', None)
df_one.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                  text  \
# ...

# %%
df_one.expanded_urls.isna().sum()
# Out:
# 58

# %%
## Get the dataframe for the missing expanded_urls data

df_one[df_one.expanded_urls.isnull()]
# Out:
#                 tweet_id           timestamp  \
# 30    886267009285017600 2017-07-15 16:51:35
# 55    881633300179243008 2017-07-02 21:58:53
# 64    879674319642796034 2017-06-27 12:14:36
# 113   870726314365509632 2017-06-02 19:38:25
# 148   863427515083354112 2017-05-13 16:15:35
# 179   857214891891077121 2017-04-26 12:48:51
# 186   856288084350160898 2017-04-23 23:26:03
# 188   855862651834028034 2017-04-22 19:15:32
# 189   855860136149123072 2017-04-22 19:05:32
# 218   850333567704068097 2017-04-07 13:04:55
# 228   848213670039564288 2017-04-01 16:41:12
# 234   847617282490613760 2017-03-31 01:11:22
# 274   840698636975636481 2017-03-11 22:59:09
# 290   838150277551247360 2017-03-04 22:12:52
# 291   838085839343206401 2017-03-04 17:56:49
# 313   835246439529840640 2017-02-24 21:54:03
# 342   832088576586297345 2017-02-16 04:45:50
# 346   831926988323639298 2017-02-15 18:03:45
# 375   828361771580813312 2017-02-05 21:56:51
# 387   826598799820865537 2017-02-01 01:11:25
# ...

# %%
## Get the dataframe where expanded_urls is not null 

df_one = df_one[df_one['expanded_urls'].notna()]

# %% [markdown]
# **Test**

# %%
df_one.expanded_urls.isnull().sum()
# Out:
# 0

# %%
# Get the dataframe again to check

df_one[df_one.expanded_urls.isnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, dog_breed_updated, favorite_count, retweet_count, retweet_status, url, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2117 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2117 non-null   object
#  1   timestamp           2117 non-null   datetime64[ns]
#  2   source              2117 non-null   object
#  3   text                2117 non-null   object
#  4   expanded_urls       2117 non-null   object
#  5   rating_numerator    2117 non-null   int64
#  6   rating_denominator  2117 non-null   int64
#  7   name                2117 non-null   category
#  8   dog_breed_updated   338 non-null    object
#  9   favorite_count      2109 non-null   float64
#  10  retweet_count       2109 non-null   float64
#  11  retweet_status      2109 non-null   object
#  12  url                 2109 non-null   object
#  13  jpg_url             1994 non-null   object
#  14  img_num             1994 non-null   category
# ...

# %% [markdown]
# #### Issue 9
# - Names of some dogs are not correct
# - Some dog names were extracted incorrectly from the text
# - While some texts do not have dog names
# - but code attached names for them
#
#
# **Define**
# - Replace names that are not capitalized as missing data (nan)
#
# **Code**

# %%
## Checking through the names to know where the 
## code got it wrong

df_one['name'].value_counts()[:30]
# Out:
# None       622
# a           55
# Lucy        11
# Charlie     11
# Cooper      10
# Oliver      10
# Penny        9
# Tucker       9
# Sadie        8
# the          8
# Lola         8
# Winston      8
# Toby         7
# Daisy        7
# Oscar        6
# Bailey       6
# Bo           6
# Stanley      6
# Jax          6
# Bella        6
# Koda         6
# an           6
# Scout        5
# Bentley      5
# Dave         5
# Milo         5
# Louis        5
# Leo          5
# Buddy        5
# Chester      5
# Name: name, dtype: int64

# %% [markdown]
# Going through the names, we found out that names like ['an', 'a', 'not', 'by', 'the', 'very', 'just', 'one', 'such','all', 'old', and etc] were misplaced names because the acompany texts do not have dog names but the code extracted names for them. They will be replaced as **`nan`**

# %%
## Confirming the name with the text 

df_one[df_one['name'] == 'Cooper']
# Out:
#                 tweet_id           timestamp  \
# 126   868552278524837888 2017-05-27 19:39:34
# 483   814986499976527872 2016-12-31 00:08:17
# 532   808001312164028416 2016-12-11 17:31:39
# 607   798209839306514432 2016-11-14 17:03:50
# 910   757611664640446465 2016-07-25 16:21:11
# 961   751132876104687617 2016-07-07 19:16:47
# 1291  708119489313951744 2016-03-11 02:36:57
# 1333  705442520700944385 2016-03-03 17:19:38
# 1395  699801817392291840 2016-02-17 03:45:29
# 1800  676975532580409345 2015-12-16 04:01:59
#
#                                                                                   source  \
# 126   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 483   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 532   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 607   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df_one.name.count()
# Out:
# 2117

# %%
## Make any name with lower case as none name

mask = df_one.name.str.islower() 
column_name = 'name' 
df_one.loc[mask, column_name] = np.nan

# %%
df_one.name.value_counts()
# Out:
# None        622
# Lucy         11
# Charlie      11
# Cooper       10
# Oliver       10
#            ...
# by            0
# all           0
# actually      0
# a             0
# very          0
# Name: name, Length: 956, dtype: int64

# %% [markdown]
# **Test**

# %%
df_one[df_one['name'] == "None"]
# Out:
#                 tweet_id           timestamp  \
# 5     891087950875897856 2017-07-29 00:08:17
# 7     890729181411237888 2017-07-28 00:22:40
# 12    889665388333682689 2017-07-25 01:55:32
# 24    887343217045368832 2017-07-18 16:08:03
# 25    887101392804085760 2017-07-18 00:07:08
# ...                  ...                 ...
# 2342  666082916733198337 2015-11-16 02:38:37
# 2343  666073100786774016 2015-11-16 01:59:36
# 2344  666071193221509120 2015-11-16 01:52:02
# 2351  666049248165822465 2015-11-16 00:24:50
# 2355  666020888022790149 2015-11-15 22:32:08
#
#                                                                                   source  \
# 5     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 7     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 12    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
## Check the null values again 

df_one.isnull().sum()
# Out:
# tweet_id                 0
# timestamp                0
# source                   0
# text                     0
# expanded_urls            0
# rating_numerator         0
# rating_denominator       0
# name                   104
# dog_breed_updated     1779
# favorite_count           8
# retweet_count            8
# retweet_status           8
# url                      8
# jpg_url                123
# img_num                123
# p1                     123
# p1_conf                123
# p1_dog                 123
# p2                     123
# p2_conf                123
# p2_dog                 123
# p3                     123
# p3_conf                123
# p3_dog                 123
# dtype: int64

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
df_one.to_csv('twitter_archive_master.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Analyzing and Visualizing Data
#
# In this section, we are producing at least **three (3) insights and one (1) visualization.**
#
# **To-do:**
# - Import the saved dataset
# - Analyse the dataset to give insights from the datasets

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %%
df.head()
# Out:
#              tweet_id            timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56
# 1  892177421306343426  2017-08-01 00:17:27
# 2  891815181378084864  2017-07-31 00:18:03
# 3  891689557279858688  2017-07-30 15:58:51
# 4  891327558926688256  2017-07-29 16:00:24
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                  text  \
# ...

# %%
df.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator  favorite_count  \
# count  2.117000e+03       2117.000000         2117.000000     2109.000000
# mean   7.363263e+17         12.246103           10.501181     7740.552394
# std    6.706417e+16         40.275298            7.105845    11285.373450
# min    6.660209e+17          0.000000            2.000000       66.000000
# 25%    6.766175e+17         10.000000           10.000000     1712.000000
# 50%    7.094095e+17         11.000000           10.000000     3523.000000
# 75%    7.873224e+17         12.000000           10.000000     9579.000000
# max    8.924206e+17       1776.000000          170.000000   144850.000000
#
#        retweet_count      img_num      p1_conf       p2_conf       p3_conf
# count    2109.000000  1994.000000  1994.000000  1.994000e+03  1.994000e+03
# mean     2293.315789     1.203109     0.593941  1.344195e-01  6.024848e-02
# std      4024.683775     0.560777     0.271954  1.006807e-01  5.089067e-02
# ...

# %% [markdown]
# ### Insight 1:
# **Do higher numerator ratings lead to more retweet_count?**
#
# `We want find the relationship between retweet_count and rating_numerator`

# %%
## Get the value count for numerator ratings

df.rating_numerator.value_counts()
# Out:
# 12      489
# 10      436
# 11      417
# 13      295
# 9       154
# 8        98
# 7        52
# 14       40
# 5        34
# 6        32
# 3        19
# 4        16
# 2         9
# 1         5
# 0         2
# 27        1
# 45        1
# 75        1
# 121       1
# 143       1
# 99        1
# 204       1
# 1776      1
# 420       1
# 144       1
# 88        1
# 84        1
# 80        1
# 60        1
# 50        1
# 44        1
# 26        1
# 24        1
# 165       1
# Name: rating_numerator, dtype: int64

# %%
# Visualizing the data distribution for each rating  

df.rating_numerator.value_counts().plot(kind='hist', color='#808000')
plt.xlabel("Number of Occurence",
            fontsize = 12)
plt.ylabel("Number of Rating",
          fontsize = 12)
plt.title('Distribution of Numerator Rating',
         fontsize = 12)
plt.xticks(rotation='vertical')
sns.despine();

# %% [markdown]
# Finding the relationship betweet retweet_count and rating_numerator by plotting a **`scatter plot`**

# %%
# plotting a scatter plot

plt.figure(figsize = (12,8))
sns.set_style('white')
sns.regplot(x = 'rating_numerator', y= 'retweet_count', data = df, color= '#808000')
plt.xlabel("Ratings",
            fontsize = 12)
plt.ylabel("Retweet Count",
          fontsize = 12)
plt.title('Relationship between Retweet Count and Numerator Rating',
         fontsize = 14)
plt.xticks(rotation='vertical')
sns.despine();

# %% [markdown]
# #### Interpretation:
#
# - Most of the data points are more concentrated between **0 - 20**
# - This also shows that we have outliers in the data
# - We can see clear that most of the retweet that had high retweet were more concentrated where ratings are between **0 - 20**
# - No rating above **20** had retweet greater than **10,000**
# - There is really no obvious relationship betweet **numerator ratings and retweet_count**

# %% [markdown]
# ### Insight 2:
# **Do higher numerator ratings lead to more favorite_count?**
#
# `We want find the relationship between favorite_count and rating_numerator by plotting scatter plot`

# %%
# plotting a scatter plot

plt.figure(figsize = (10,7))
sns.set_style('white')
sns.regplot(x='rating_numerator',
           y='favorite_count',
            data = df,
           color='#808000')
plt.xlabel("Ratings",
            fontsize = 12)
plt.ylabel("Favorite Count",
          fontsize = 12)
plt.title('Relationship between Favorite Count and Numerator Rating',
         fontsize = 14)
plt.xticks(rotation='vertical')
sns.despine();

# %% [markdown]
# #### Interpretation:
# Like retweet count in insight 1;
# - Most of the data points are more concentrated between **0 - 20**
# - This also shows that we have outliers in the data
# - We can see clearly that most of the tweet that had high favorite count were more concentrated where ratings are between **0 - 20**
# - No rating above **20** had retweet greater than **30,000**
# - There is really no obvious relationship between **numerator ratings and favourite_count**

# %% [markdown]
# ### Insight 3:
#
# **What the relationship between favorite_count and retweet_count?**
#
# We would find the correlation between favorite_count and retweet_count. This will be plotted on scatter plot

# %%
# plotting a scatter plot

plt.figure(figsize = (10,8 ))
sns.set_style('white')
sns.regplot(x='favorite_count',
           y='retweet_count',
            data = df,
           color='#808000')
plt.xlabel("favorite_count",
            fontsize = 12)
plt.ylabel("Retweet Count",
          fontsize = 12)
plt.title('Relationship between Retweet Count and Favorite Count',
         fontsize = 14)
plt.xticks(rotation='vertical')
sns.despine();

# %% [markdown]
# #### Interpretation:
# - There is a positive relationship between favorite_count and retweet_count
# - The visual shows that there is high possibility of WeRateDogs tweet get retweeted by users when the users liked the tweet

# %% [markdown]
# ### Insight 4:
# **Which one of the dog breed is the most famous of all the dog breeds?**
#
# `We will visualize this by plotting count of dog_breed_updated in a bar chart`

# %%
## visualizing the data distribution 

df.dog_breed_updated.value_counts().plot(kind='hist', color='#808000')
plt.xlabel("Number of Occurence",
            fontsize = 12)
plt.ylabel("Number of Dog Breed",
          fontsize = 12)
plt.title('Dog Breed Distribution',
         fontsize = 12)
plt.xticks(rotation='vertical')
sns.despine();

# %%
df_bar = df.dog_breed_updated.value_counts()
df_bar
# Out:
# pupper        222
# doggo          72
# puppo          23
# multi_type     12
# floofer         9
# Name: dog_breed_updated, dtype: int64

# %%
plt.figure(figsize = (10,8 ))
sns.set_style('white')
plt.bar(x=df_bar.index,
        height=df_bar.sort_values(ascending=False),
           color='#808000')
plt.xlabel("Dog Breed",
            fontsize = 12)
plt.ylabel("Number of Breeds",
          fontsize = 12)
plt.title('Distribution of Dog Breed',
         fontsize = 14)
plt.xticks(rotation='horizontal',
          fontsize = 12)
sns.despine();

# %% [markdown]
# #### Interpretation:
# - The most famous breed of all is **PUPPER** followed by **DOGGO**
# - **DOGGO** came a distance second
# - The less popular breed of all was **FLOOFER**

# %% [markdown]
# ### Insight 5:
# **Of all the images supplied to each algorithm, which category of image numbers supplied to the algorithms have the highest percentage?**
#
# `We will get the value counts for img_num category and plot this result in a pie chart`

# %%
df_pie = df.img_num.value_counts()
df_pie
# Out:
# 1.0    1711
# 2.0     191
# 3.0      62
# 4.0      30
# Name: img_num, dtype: int64

# %%
# Visualizing the percentage of overall number of images to each category
# through pie chart

colors = ['#808000','#006400','#F08080','#BC8F8F']
plt.figure(figsize = (12,13))
plt.pie(df_pie,
       labels = df_pie.index,
       autopct = '%.2f%%',
       colors = colors,
       textprops = {'size': 'x-large',
                   'fontweight': 'bold',
                   'rotation': '25',
                   'color': 'w'})
plt.title('% of Image Number Category Supplied to the Algorithms', fontsize=14)
plt.legend(bbox_to_anchor=(0.93, 0.8),loc = 'lower right');

# %% [markdown]
# #### Interpretation:
# - **85.77%** of the images supplied to the algorithms were single **(1.0)** image
# - So, the image categroy **1.0** is the most frequent
